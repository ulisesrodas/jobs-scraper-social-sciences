# %%
import pandas as pd

# 1. Cargamos el archivo
df = pd.read_csv("convocatorias_sociales_pe.csv", encoding="utf-8")

# 2. Le decimos a Pandas que no corte el texto largo en las columnas
pd.set_option('display.max_colwidth', None)

# 3. Mostramos las primeras 50 filas de la columna 'description' como Data Frame
df[['description']].head(50)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
# Leemos el CSV forzando la codificación utf-8
df = pd.read_csv("convocatorias_sociales_pe.csv", encoding="utf-8")

# Mostramos las primeras filas para comprobar que las tildes y eñes se ven perfectas
display(df.head(50))
# Out:
#                      id      site  \
# 0   in-6f9b4a70148f6a96    indeed
# 1   in-c06ca0fc0b2a3d7c    indeed
# 2   in-5040e485810dd595    indeed
# 3   in-30c6bea2e225e1c2    indeed
# 4   in-cef67bc069fd8396    indeed
# 5   in-db49d0e47bd2e5df    indeed
# 6   in-8e15d89de8ad7280    indeed
# 7   in-bbb01d499f332cd7    indeed
# 8   in-19e2df9bb91b5142    indeed
# 9   in-234244862e187d2d    indeed
# 10  in-90712c7b47d618ce    indeed
# 11  in-ee9cced925aad7ac    indeed
# 12  in-798a280900fe82f0    indeed
# 13  in-916d61036c67e7a1    indeed
# 14  in-b70be5327e41794a    indeed
# 15  in-3e25a6fcc1a564c2    indeed
# 16  in-a484976dbb7b233c    indeed
# 17  in-75c8e5790321547e    indeed
# 18  in-52af1c7df8a8c6d0    indeed
# 19  in-cfbe1a6c33c7c0a2    indeed
# 20  in-11979d1d67a9692b    indeed
# 21  in-64af094f59c8adc4    indeed
# 22  in-6c4cdc75867c7b43    indeed
# 23  in-b9241fce1ef6a239    indeed
# 24  in-8bbfe23eb374417a    indeed
# 25  in-69cee65da9780260    indeed
# ...
